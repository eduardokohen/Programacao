# %% [markdown]
# <div align="center">
# <img width="80%" src="https://user-images.githubusercontent.com/73097560/115834477-dbab4500-a447-11eb-908a-139a6edaec5c.gif"/>
#
# <div align="center">
#
# <img src="https://raw.githubusercontent.com/devicons/devicon/master/icons/python/python-original.svg" alt="Python" width="80" height="80"/>
#
# <h1 style="font-size: 2.5em; color: #e6e6e6; margin: 10px 0;">
# </h1>
#
# <h2 style="font-size: 2.5em; color: #e6e6e6; margin: 10px 0;">
#    Iniciando em Data Science: Aprendendo Python
# </h2>
#
# <h3 style="color: #a8b2d1; font-weight: 400; margin: 10px 0;">
#   PhD. Julles Mitoura
# </h3>
#
# <p style="margin: 10px 0;">
#   <img src="https://img.shields.io/badge/Python-3776AB?style=for-the-badge&logo=python&logoColor=white" alt="Python"/>
#   <img src="https://img.shields.io/badge/Data_Science-FF6F00?style=for-the-badge&logo=jupyter&logoColor=white" alt="Data Science"/>
#   <img src="https://img.shields.io/badge/Alura-0078D4?style=for-the-badge&logo=&logoColor=white" alt="Alura"/>
# </p>
#
# <img width="80%" src="https://user-images.githubusercontent.com/73097560/115834477-dbab4500-a447-11eb-908a-139a6edaec5c.gif"/>
#
# </div>

# %% [markdown]
# # **Módulo 5**: Estruturas de Dados
#
# ---
# ## Projeto: Extração de Dados e Geração de Relatório
#
# Neste projeto, você vai criar um sistema que integra todos os conceitos aprendidos:
#
# - Leitura de arquivos CSV
# - Processamento de dados com listas e dicionários
# - Compreensões de listas e dicionários
# - Geração de relatórios formatados
# - Trabalho com arquivos de texto
#
# Vamos construir um sistema completo e funcional!
#
# ---

# %% [markdown]
# ## Objetivo do projeto
#
# Você vai construir um pipeline simples:
#
# 1. **Ler** `vendas.csv`
# 2. **Processar** (totais, médias, destaques)
# 3. **Agrupar** por produto
# 4. **Gerar e salvar** um relatório `.txt`
#
# Vamos fazer passo a passo, organizando o código de forma clara.
#
# ---

# %%
# Importe o módulo csv
# Escreva seu código aqui

# %% [markdown]
# ## 1. Carregar dados do CSV
#
# Primeiro, vamos ler o arquivo `vendas.csv` e converter os tipos de dados.

# %%
# Carregue vendas.csv, converta tipos e armazene em uma lista
# Escreva seu código aqui

# %% [markdown]
# ## 2. Validar dados
#
# Vamos verificar se há erros nos dados carregados.

# %%
# Valide os dados: verifique se vendas está vazia, se Produto é válido, Quantidade > 0 e Preco > 0
# Escreva seu código aqui

# %% [markdown]
# ## 3. Calcular valores totais e estatísticas
#
# Vamos adicionar o valor total de cada venda e calcular as estatísticas gerais.

# %%
# Calcule ValorTotal para cada venda e as estatísticas gerais (total_registros, total_unidades, valor_total, valor_medio)
# Escreva seu código aqui

# %% [markdown]
# ## 4. Agrupar por produto
#
# Vamos agrupar as vendas por produto e encontrar os destaques.

# %%
# Agrupe as vendas por produto, somando quantidade_total e valor_total
# Escreva seu código aqui

# %%
# Encontre o produto com maior quantidade_total e o com maior valor_total (sem usar lambda)
# Escreva seu código aqui

# %% [markdown]
# ## 5. Gerar relatório
#
# Vamos montar o texto completo do relatório formatado.

# %%
# Crie o cabeçalho do relatório, adicione estatísticas gerais e destaques
# Escreva seu código aqui

# %%
# Adicione o detalhamento por produto (ordenado por faturamento) e finalize o relatório
# Escreva seu código aqui

# %% [markdown]
# ## 6. Visualizar e salvar relatório
#
# Vamos ver uma prévia do relatório e salvá-lo em arquivo.

# %%
# Mostre uma prévia das primeiras 20 linhas do relatório
# Escreva seu código aqui

# %%
# Salve o relatório em "relatorio_vendas.txt"
# Escreva seu código aqui

# %% [markdown]
# ---
#
# ## Resumo do projeto
#
# Você aplicou:
#
# - leitura de CSV (`csv.DictReader`)
# - listas/dicionários para organizar e agrupar
# - compreensões de listas
# - geração e escrita de relatório `.txt`
# - validação de dados
#
# A partir daqui, você pode evoluir o projeto com desafios extras.
#
# ---
#
# ## **Resumo do Módulo 5**
#
# Você completou o módulo de Estruturas de Dados. Aqui está o que você dominou:
#
# ### **Conceitos Fundamentais**
# 1. **Listas, Tuplas e Dicionários**: As três estruturas básicas de dados em Python
# 2. **Matrizes**: Como trabalhar com listas de listas
# 3. **Compreensões**: Forma concisa e eficiente de criar listas e dicionários
# 4. **Arquivos**: Leitura e escrita de arquivos de texto e CSV
#
#
# ### **Projeto Final**
# Você criou um sistema completo que:
# - Lê dados de um arquivo CSV
# - Valida e processa os dados
# - Calcula estatísticas e agregações
# - Gera um relatório formatado em arquivo de texto
#
# Continue praticando e explorando novas possibilidades com esses conceitos fundamentais!
