# %% [markdown]
# <div align="center">
# <img width="80%" src="https://user-images.githubusercontent.com/73097560/115834477-dbab4500-a447-11eb-908a-139a6edaec5c.gif"/>
#
# <div align="center">
#
# <img src="https://raw.githubusercontent.com/devicons/devicon/master/icons/python/python-original.svg" alt="Python" width="80" height="80"/>
#
# <h1 style="font-size: 2.5em; color: #e6e6e6; margin: 10px 0;">
# </h1>
#
# <h2 style="font-size: 2.5em; color: #e6e6e6; margin: 10px 0;">
#    Iniciando em Data Science: Aprendendo Python
# </h2>
#
# <h3 style="color: #a8b2d1; font-weight: 400; margin: 10px 0;">
#   PhD. Julles Mitoura
# </h3>
#
# <p style="margin: 10px 0;">
#   <img src="https://img.shields.io/badge/Python-3776AB?style=for-the-badge&logo=python&logoColor=white" alt="Python"/>
#   <img src="https://img.shields.io/badge/Data_Science-FF6F00?style=for-the-badge&logo=jupyter&logoColor=white" alt="Data Science"/>
#   <img src="https://img.shields.io/badge/Alura-0078D4?style=for-the-badge&logo=&logoColor=white" alt="Alura"/>
# </p>
#
# <img width="80%" src="https://user-images.githubusercontent.com/73097560/115834477-dbab4500-a447-11eb-908a-139a6edaec5c.gif"/>
#
# </div>

# %% [markdown]
# # **Módulo 2**
# ## **Projeto: Sistema de Cadastro de Alunos**
#
# ---
#
# Fala, Dev!
# Neste projeto, você vai criar um **Sistema de Cadastro de Alunos** que integra todos os conceitos aprendidos:
#
# - Tipos primitivos (int, float, str, bool)
# - Operadores aritméticos, relacionais e lógicos
# - Conversão de tipos
# - Manipulação de strings e f-strings
#
#
# Para este projeto, podemos seguir o seguinte plano:
# 1. Antes de iniciar a aula, você pode tentar executar o projeto e entender as etapas envolvidas.
# 2. Acompanhar o desenvolvimento em aula.
# 3. Tentar replicar o projeto.
#
# Vamos nessa!
#
# ---

# %% [markdown]
# ## **Objetivo do Projeto**
#
# Criar um sistema que:
# 1. Cadastra informações de alunos
# 2. Calcula a média das notas
# 3. Verifica se o aluno foi aprovado
# 4. Gera um relatório formatado
# 5. Valida os dados de entrada

# %% [markdown]
# ---
#
# ## Parte 1: Cadastro de Dados do Aluno
#
# Primeiro, vamos criar as variáveis para armazenar os dados do aluno.

# %%
# Dados do Aluno
# Crie variáveis para nome, idade, email e matrícula
# Crie variáveis para as notas (como texto, como em um formulário)
# Imprima um cabeçalho "CADASTRO DE ALUNO" e exiba os dados
# Escreva seu código aqui

# %% [markdown]
# ## Parte 2: Validação de Dados
#
# Vamos validar os dados do aluno antes de processar.

# %%
# Validação do Email
# Verifique se o email contém "@", não tem espaços e tem pelo menos 5 caracteres

# Validação da Idade
# Verifique se a idade é maior que 0 e menor que 120

# Validação do Nome
# Verifique se o nome não está vazio (após remover espaços)

# Validação geral
# Combine todas as validações usando operadores lógicos

# Imprima os resultados das validações
# Escreva seu código aqui

# %% [markdown]
# ## Parte 3: Conversão e Cálculo de Notas
#
# Agora vamos converter as notas de texto para números e calcular a média.

# %%
# Converter notas de texto para float
# Use float() para converter cada nota

# Calcular a média
# Some as três notas e divida por 3

# Imprima um cabeçalho "CÁLCULO DE NOTAS" e exiba as notas e a média
# Escreva seu código aqui

# %% [markdown]
# ## Parte 4: Verificação de Aprovação
#
# Vamos verificar se o aluno foi aprovado (média >= 7.0).

# %%
# Verificar aprovação
# Defina a nota mínima como 7.0
# Verifique se foi aprovado (média >= nota_minima)

# Verificar se está em recuperação (média entre 5.0 e 6.9)
# Use operadores relacionais e lógicos

# Verificar se foi reprovado (média < 5.0)

# Imprima um cabeçalho "VERIFICAÇÃO DE APROVAÇÃO" e exiba os resultados
# Escreva seu código aqui

# %% [markdown]
# ## Parte 5: Formatação e Limpeza de Dados
#
# Vamos limpar e formatar os dados do aluno para exibição.

# %%
# Limpar e formatar o nome
# Use strip() para remover espaços extras e title() para capitalizar

# Formatar email
# Use strip() para remover espaços e lower() para minúsculas

# Imprima um cabeçalho "FORMATAÇÃO DE DADOS" e exiba os dados originais e formatados
# Escreva seu código aqui

# %% [markdown]
# ## Parte 6: Geração do Relatório Final
#
# Agora vamos criar um relatório completo e formatado usando f-strings!

# %%
# Gerar relatório formatado
# Calcule os pontos necessários para aprovação (se não aprovado)
# Crie um relatório usando f-strings com:
#   - Cabeçalho formatado
#   - Dados do aluno
#   - Notas e média
#   - Resultado (aprovado, recuperação, reprovado)
#   - Pontos necessários
# Escreva seu código aqui

# %%
# Estatísticas adicionais
# Use max() para encontrar a maior nota
# Use min() para encontrar a menor nota
# Calcule a diferença entre maior e menor nota
# Imprima as estatísticas
# Escreva seu código aqui

# %% [markdown]
# ---
