# %% [markdown]
# <div align="center">
# <img width="80%" src="https://user-images.githubusercontent.com/73097560/115834477-dbab4500-a447-11eb-908a-139a6edaec5c.gif"/>
#
# <div align="center">
#
# <img src="https://raw.githubusercontent.com/devicons/devicon/master/icons/python/python-original.svg" alt="Python" width="80" height="80"/>
#
# <h1 style="font-size: 2.5em; color: #e6e6e6; margin: 10px 0;">
# </h1>
#
# <h2 style="font-size: 2.5em; color: #e6e6e6; margin: 10px 0;">
#    Iniciando em Data Science: Aprendendo Python
# </h2>
#
# <h3 style="color: #a8b2d1; font-weight: 400; margin: 10px 0;">
#   PhD. Julles Mitoura
# </h3>
#
# <p style="margin: 10px 0;">
#   <img src="https://img.shields.io/badge/Python-3776AB?style=for-the-badge&logo=python&logoColor=white" alt="Python"/>
#   <img src="https://img.shields.io/badge/Data_Science-FF6F00?style=for-the-badge&logo=jupyter&logoColor=white" alt="Data Science"/>
#   <img src="https://img.shields.io/badge/Alura-0078D4?style=for-the-badge&logo=&logoColor=white" alt="Alura"/>
# </p>
#
# <img width="80%" src="https://user-images.githubusercontent.com/73097560/115834477-dbab4500-a447-11eb-908a-139a6edaec5c.gif"/>
#
# </div>

# %% [markdown]
# # **Módulo 2**: Variáveis, Tipos e Operadores
#
# ---
#
# # **Aula 3: Manipulação de Strings e F-strings**
#
# Nesta aula, você vai aprender:
# - Como trabalhar com strings (textos) em Python
# - Métodos úteis para manipular strings
# - Como formatar textos com f-strings
# - Como criar mensagens dinâmicas e profissionais
#
# Bem como os demais tipos de variáveis, `Strings` é sempre muito presente ao longo da nossa jornada como programador. Dedicaremos essa terceira aula para esturar `Strings` e `F-Strings`. Vamos nessa!
#
# ---

# %% [markdown]
# ## **1. O que são Strings?**
#
# **String** é o nome técnico para texto em programação. Em Python, strings são sequências de caracteres entre aspas simples (`'`) ou duplas (`"`).
#
# ```python
# nome = "Python"
# mensagem = 'Olá, mundo!'
# ```
#
# Vamos ver o que podemos fazer com strings!

# %%
# Criando strings
# Crie variáveis para nome, linguagem e mensagem
# Imprima-as e verifique o tipo usando type()
# Escreva seu código aqui

# %% [markdown]
# ## **2. Concatenação de Strings**
#
# **Concatenar** significa juntar strings. Podemos fazer isso com o operador `+`.

# %%
# Concatenando strings
# Crie variáveis nome e sobrenome
# Concatene-as para formar o nome completo
# Crie uma mensagem de boas-vindas concatenando strings
# Escreva seu código aqui

# %% [markdown]
# ## **3. Métodos Úteis para Manipular Strings**
#
# Principais métodos: `upper()`, `lower()`, `strip()`, `replace()`, `len()`, `in`

# %% [markdown]
# ### **3.1 Exemplos de Métodos**

# %%
# Exemplos de métodos de string
# Crie uma variável texto com espaços no início e fim
# Teste os métodos: upper(), lower(), strip(), replace(), len(), in
# Escreva seu código aqui

# %% [markdown]
# ## **4. F-strings (Formatação de Strings)**
#
# **F-strings** são a forma moderna e mais fácil de formatar strings em Python. Elas permitem inserir variáveis diretamente no texto!
#
# Para usar f-strings, coloque um `f` antes das aspas: `f"texto {variavel}"`

# %%
# Exemplo básico de f-string
# Crie variáveis nome e idade
# Crie uma mensagem usando concatenação (forma antiga)
# Crie uma mensagem usando f-string (forma moderna)
# Escreva seu código aqui

# %% [markdown]
# ### **4.1 F-strings com Cálculos**
#
# Você pode fazer cálculos diretamente dentro das f-strings!

# %%
# Fazer cálculos dentro da f-string
# Crie variáveis para preço e quantidade
# Crie uma mensagem mostrando o total calculado dentro da f-string
# Crie variáveis para notas e calcule a média dentro da f-string
# Escreva seu código aqui

# %% [markdown]
# ### **4.2 Formatação de Números com F-strings**
#
# Podemos formatar números para mostrar com casas decimais específicas ou separadores.

# %%
# Formatação de números
# Crie variáveis para preço e pi
# Formate o preço com 2 casas decimais
# Formate pi com 3 casas decimais
# Formate o preço sem casas decimais
# Formate um desconto como porcentagem
# Escreva seu código aqui

# %% [markdown]
# ### **4.3 Exemplos Práticos com F-strings**

# %%
# Exemplo 1: Recibo de compra
# Crie variáveis para produto, preço unitário, quantidade e desconto
# Calcule subtotal, valor do desconto e total
# Crie um recibo formatado usando f-strings
# Escreva seu código aqui

# %%
# Exemplo 2: Boas-vindas personalizadas
# Crie variáveis para nome, idade e cidade
# Crie uma mensagem de boas-vindas usando f-string com múltiplas linhas
# Escreva seu código aqui

# %% [markdown]
# ## **5. Combinando Tudo**
#
# Vamos usar vários métodos juntos para criar textos profissionais!

# %%
# Exemplo: Processar dados de um formulário
# Crie variáveis nome_usuario e email_usuario com espaços e maiúsculas
# Limpe e formate usando strip(), title(), lower()
# Crie uma mensagem de boas-vindas formatada
# Escreva seu código aqui

# %% [markdown]
# ## **6. Indexização de Strings**
#
# Em Python, podemos acessar caracteres individuais de uma string usando **índices**. Os índices começam em 0 (primeiro caractere) e vão até o tamanho da string menos 1.
#
# **Sintaxe:** `string[indice]`
#
# Também podemos usar **slicing** (fatiamento) para pegar partes da string: `string[inicio:fim]`

# %%
# Exemplos de indexização
# Crie uma variável texto = "Python"
# Acesse o primeiro, segundo, último e penúltimo caractere
# Use slicing para pegar partes da string
# Crie uma variável nome completo e extraia primeiro nome e sobrenome
# Escreva seu código aqui

# %% [markdown]
# ## **7. Exercício Práticos**
#
# Agora é sua vez! Tente resolver o exercício abaixo.
#
# ### **Exercício 1: Formatação de Nome**
#
# Crie uma variável `nome` com o valor `"  joão silva  "` (com espaços e minúsculas).
# Use métodos de string para:
# 1. Remover os espaços
# 2. Capitalizar (primeira letra maiúscula)
# 3. Criar uma mensagem de boas-vindas usando f-string

# %%
# Escreva seu código aqui
