# %% [markdown]
# <div align="center">
# <img width="80%" src="https://user-images.githubusercontent.com/73097560/115834477-dbab4500-a447-11eb-908a-139a6edaec5c.gif"/>
#
# <div align="center">
#
# <img src="https://raw.githubusercontent.com/devicons/devicon/master/icons/python/python-original.svg" alt="Python" width="80" height="80"/>
#
# <h1 style="font-size: 2.5em; color: #e6e6e6; margin: 10px 0;">
# </h1>
#
# <h2 style="font-size: 2.5em; color: #e6e6e6; margin: 10px 0;">
#    Iniciando em Data Science: Aprendendo Python
# </h2>
#
# <h3 style="color: #a8b2d1; font-weight: 400; margin: 10px 0;">
#   PhD. Julles Mitoura
# </h3>
#
# <p style="margin: 10px 0;">
#   <img src="https://img.shields.io/badge/Python-3776AB?style=for-the-badge&logo=python&logoColor=white" alt="Python"/>
#   <img src="https://img.shields.io/badge/Data_Science-FF6F00?style=for-the-badge&logo=jupyter&logoColor=white" alt="Data Science"/>
#   <img src="https://img.shields.io/badge/Alura-0078D4?style=for-the-badge&logo=&logoColor=white" alt="Alura"/>
# </p>
#
# <img width="80%" src="https://user-images.githubusercontent.com/73097560/115834477-dbab4500-a447-11eb-908a-139a6edaec5c.gif"/>
#
# </div>

# %% [markdown]
# # **Módulo 2**: Variáveis, Tipos e Operadores
#
# ---
#
# # Aula 2: Operadores Aritméticos, Relacionais e Lógicos
#
# Nesta aula, falaremos sobre:
# - Como usar operadores aritméticos para fazer cálculos
# - Como comparar valores usando operadores relacionais
# - Como combinar condições com operadores lógicos
#
# Os operadores aritméticos, relacionais e lógicos são conceitos fundamentais e muito importantes para programação com Python. Em diversos casos você vai precisar fazer cálculos, comparar valores e fazer operações lógicas para definir fluxos... enfim, vamos nessa para mais uma aula.
#
# ---

# %% [markdown]
# ## **1. Operadores Aritméticos**
#
# Operadores aritméticos são símbolos que usamos para fazer cálculos matemáticos.
#
# | Operador | Símbolo | Exemplo | Resultado |
# |----------|---------|---------|-----------|
# | Soma | `+` | `5 + 3` | `8` |
# | Subtração | `-` | `10 - 4` | `6` |
# | Multiplicação | `*` | `3 * 4` | `12` |
# | Divisão | `/` | `15 / 3` | `5.0` |
# | Divisão inteira | `//` | `15 // 4` | `3` |
# | Resto (módulo) | `%` | `15 % 4` | `3` |
# | Potência | `**` | `2 ** 3` | `8` |

# %%
# Vamos testar os operadores aritméticos
# Crie variáveis a = 10 e b = 3
# Teste todos os operadores aritméticos e imprima os resultados
# Escreva seu código aqui

# %% [markdown]
# ### **1.1 Exemplo Prático**

# %%
# Cálculo de média de notas
# Crie três variáveis para notas e calcule a média
# Escreva seu código aqui

# %% [markdown]
# ---
#
# ## **2. Operadores Relacionais**
#
# Operadores relacionais (também chamados de **comparação**) são usados para comparar valores. Eles sempre retornam `True` ou `False`.
#
# | Operador | Significado | Exemplo | Resultado |
# |----------|-------------|---------|-----------|
# | `==` | Igual a | `5 == 5` | `True` |
# | `!=` | Diferente de | `5 != 3` | `True` |
# | `>` | Maior que | `10 > 5` | `True` |
# | `<` | Menor que | `3 < 7` | `True` |
# | `>=` | Maior ou igual | `5 >= 5` | `True` |
# | `<=` | Menor ou igual | `4 <= 6` | `True` |

# %%
# Vamos testar os operadores relacionais
# Crie variáveis a = 10, b = 5, c = 10
# Teste todos os operadores relacionais e imprima os resultados
# Escreva seu código aqui

# %% [markdown]
# ### **2.1 Comparando Strings**
#
# Podemos comparar strings alfabeticamente.

# %%
# Comparando strings
# Crie variáveis nome1, nome2, nome3 e compare-as
# Escreva seu código aqui

# %% [markdown]
# ### **2.2 Exemplo Prático**

# %%
# Verificar aprovação
# Crie variáveis para nota e idade
# Verifique se foi aprovado (nota >= 7.0) e se pode votar (idade >= 16)
# Escreva seu código aqui

# %% [markdown]
# ---
#
# ## **3. Operadores Lógicos**
#
# Operadores lógicos são usados para combinar condições. Eles trabalham com valores booleanos (`True` e `False`).
#
# | Operador | Significado | Exemplo | Resultado |
# |----------|-------------|---------|-----------|
# | `and` | E (ambas condições verdadeiras) | `True and False` | `False` |
# | `or` | OU (pelo menos uma verdadeira) | `True or False` | `True` |
# | `not` | NÃO (inverte o valor) | `not True` | `False` |

# %%
# Testando operadores lógicos
# Teste os operadores and, or e not com diferentes combinações de True e False
# Escreva seu código aqui

# %% [markdown]
# ### **3.1 Exemplo Prático**

# %%
# Exemplos práticos
# Crie variáveis para idade, tem_carteira, nota e numero
# Use operadores lógicos para verificar condições combinadas
# Escreva seu código aqui

# %% [markdown]
# ## **4. Exercício Prático**
#
# Verifique se uma pessoa pode entrar em um evento: precisa ter 18 anos OU ter convite.

# %%
# Escreva seu código aqui

# %% [markdown]
# ---
