# %% [markdown]
# <div align="center">
# <img width="80%" src="https://user-images.githubusercontent.com/73097560/115834477-dbab4500-a447-11eb-908a-139a6edaec5c.gif"/>
#
# <div align="center">
#
# <img src="https://raw.githubusercontent.com/devicons/devicon/master/icons/python/python-original.svg" alt="Python" width="80" height="80"/>
#
# <h1 style="font-size: 2.5em; color: #e6e6e6; margin: 10px 0;">
# </h1>
#
# <h2 style="font-size: 2.5em; color: #e6e6e6; margin: 10px 0;">
#    Iniciando em Data Science: Aprendendo Python
# </h2>
#
# <h3 style="color: #a8b2d1; font-weight: 400; margin: 10px 0;">
#   PhD. Julles Mitoura
# </h3>
#
# <p style="margin: 10px 0;">
#   <img src="https://img.shields.io/badge/Python-3776AB?style=for-the-badge&logo=python&logoColor=white" alt="Python"/>
#   <img src="https://img.shields.io/badge/Data_Science-FF6F00?style=for-the-badge&logo=jupyter&logoColor=white" alt="Data Science"/>
#   <img src="https://img.shields.io/badge/Alura-0078D4?style=for-the-badge&logo=&logoColor=white" alt="Alura"/>
# </p>
#
# <img width="80%" src="https://user-images.githubusercontent.com/73097560/115834477-dbab4500-a447-11eb-908a-139a6edaec5c.gif"/>
#
# </div>

# %% [markdown]
# # **Módulo 2**: Variáveis, Tipos e Operadores
#
# ---
# ## Aula 1: Tipos Primitivos e Conversão de Tipos
#
# Nesta aula, falaremos sobre:
#
# - O que são tipos primitivos em Python
# - Como trabalhar com números inteiros (int) e decimais (float)
# - Como trabalhar com texto (str) e valores lógicos (bool)
# - Como converter um tipo de dado em outro
#
#
# Este é um tópico essencial pois durante toda a sua carreira você seguirá utilizando estes tipos de variáveis e fazendo conversões de tipos.
#
# ---

# %% [markdown]
# ## **1. O que são Variáveis?**
#
# Uma **variável** é como uma caixa onde guardamos informações.
#
# Em Python, podemos criar variáveis facilmente:
#
# ```python
# nome = "Maria"
# idade = 25
# ```
#
# Aqui, criamos duas variáveis:
# - `nome` guarda o texto "Maria"
# - `idade` guarda o número 25
#
#
# **Importante:** Em Python, não precisamos "declarar" o tipo da variável. O Python descobre automaticamente!

# %%
# Vamos criar algumas variáveis e ver o que acontece
# Escreva seu código aqui

# %% [markdown]
# ---
#
# ## 2. Tipos Primitivos em Python
#
# Python tem 4 tipos primitivos principais:
# - **int** (inteiro): 1, 2, 100, -5
# - **float** (decimal): 3.14, 2.5, -0.5
# - **str** (string/texto): "Olá", "Python"
# - **bool** (booleano): True ou False

# %% [markdown]
# ### 2.1 Tipos Numéricos (int e float)

# %%
# Exemplos de números
# Crie variáveis para idade, preço, ano e altura
# Use type() para verificar o tipo de cada variável
# Escreva seu código aqui

# %% [markdown]
# ### 2.2 Tipos de Texto e Lógicos (str e bool)

# %%
# Exemplos de strings e booleanos
# Crie variáveis para nome, mensagem, tem_carteira e e_maior_idade
# Use type() para verificar o tipo de cada variável
# Escreva seu código aqui

# %% [markdown]
# ## 3. Conversão de Tipos
#
# Python oferece funções para converter tipos: `int()`, `float()`, `str()`, `bool()`

# %% [markdown]
# ### **3.1 Exemplos de Conversão**

# %%
# Exemplos de conversão
# Converta "42" para int
# Converta "19.99" para float
# Converta 25 para string
# Faça um cálculo com os valores convertidos
# Escreva seu código aqui

# %%
# Exemplo prático: calcular total de compra com preços em texto
# Converta os preços de texto para float e calcule o total
# Escreva seu código aqui

# %% [markdown]
# ---
#
# ## 4. Exercício Prático
#
# Calcule o salário semanal e mensal de João, que trabalha 40 horas por semana e ganha R$ 25,50 por hora (considere 4 semanas no mês).

# %%
# Escreva seu código aqui

# %% [markdown]
# ---
